# %%
import json, requests
import pandas as pd
from math import *
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
apiKey = 'AIzaSyBivgq7ZMvCFNeGgEiw3nm-zbHHnC8YCwo'
locations = pd.read_excel('Markel_Sample_Data_v4.xlsx', sheet_name = 'For_Augmentation')
locations = locations[locations['Type'] == 'Target']

# %%
def concatTypes(typeList):
    typeString = ''
    for aType in typeList:
        typeString=typeString+aType+','
    return typeString[:-1]

# %%
for name in locations.columns:
    print(name)
# Out:
# Type
# ContractID
# LocationID
# LocationName
# InceptionDate
# ExpirationDate
# Street
# City
# Area
# SubArea
# CRESTA
# PostalCode
# Country
# Latitude
# Longitude
# BuildingValue
# OtherValue
# ContentsValue
# TimeElementValue
# TotalTIV
# DaysCovered
# Currency
# RiskCount
# OccupancyCodeType
# OccupancyCode
# ConstructionCodeType
# ConstructionCode
# ConstructionOther
# YearBuilt
# NumberOfStories
# LocPerils-1
# LocLimitType-1
# LimitBldg-1
# LimitOther-1
# LimitContent-1
# LimitTime-1
# DeductType-1
# DeductBldg-1
# DeductOther-1
# DeductContent-1
# DeductTime-1
# SublimitArea-1
# LocPerils-2
# LocLimitType-2
# LimitBldg-2
# LimitOther-2
# LimitContent-2
# LimitTime-2
# DeductType-2
# DeductBldg-2
# DeductOther-2
# DeductContent-2
# DeductTime-2
# SublimitArea-2
# LocPerils-3
# LocLimitType-3
# LimitBldg-3
# LimitOther-3
# LimitContent-3
# LimitTime-3
# DeductType-3
# DeductBldg-3
# DeductOther-3
# DeductContent-3
# DeductTime-3
# SublimitArea-3
# LocPerils-4
# LocLimitType-4
# LimitBldg-4
# LimitOther-4
# LimitContent-4
# LimitTime-4
# DeductType-4
# DeductBldg-4
# DeductOther-4
# DeductContent-4
# DeductTime-4
# SublimitArea-4
# LocPerils-5
# LocLimitType-5
# LimitBldg-5
# LimitOther-5
# LimitContent-5
# LimitTime-5
# DeductType-5
# DeductBldg-5
# DeductOther-5
# DeductContent-5
# DeductTime-5
# SublimitArea-5
# LocPerils-6
# LocLimitType-6
# LimitBldg-6
# LimitOther-6
# LimitContent-6
# LimitTime-6
# DeductType-6
# DeductBldg-6
# DeductOther-6
# DeductContent-6
# DeductTime-6
# SublimitArea-6
# AppurtenantStructure
# BuildingCondition
# BuildingExteriorOpening
# BuildingShape
# Equipment
# ExternalDoors
# FloorOfInterest
# FoundationType
# FoundationConnection
# GlassType
# InternalPartition
# LargeMissile
# Ornamentation
# Pounding
# Redundancy
# RetrofitMeasures
# RoofAnchorage
# RoofAttachedStructure
# RoofCover
# RoofDeckAttachment
# RoofGeometry
# RoofPitch
# RoofYearBuilt
# ShortColumn
# SmallDebris
# SoftStory
# Tank
# TreeExposure
# Torsion
# WallAttachedStructure
# WallSiding
# WallType
# WindowProtection
# IsTenant
# LocationGroup
# IsPrimaryLocation
# ParentLocation
# Geocoder
# GeoMatchLevel
# BuildingHeight
# BuildingHeightUnitCode
# FloorArea
# FloorAreaUnitCode

# %%
locations['City']
# Out:
# 0                MIAMI
# 1        SAN FRANCISCO
# 2        SAN FRANCISCO
# 3          LOS ANGELES
# 4        SAN FRANCISCO
#              ...
# 14464        ABBEVILLE
# 14465           EUNICE
# 14466           ORANGE
# 14467     BELLE CHASSE
# 14468      FORT PIERCE
# Name: City, Length: 1008, dtype: object

# %%
masterResults = pd.DataFrame.from_dict({'G_Name':[], 'G_Vicinity':[], 'G_Latitude':[], 'G_Longitude':[], 'G_Types':[], 'G_PlaceID':[], 'LocationID':[]})
pointSearch = 0
for i, row in locations.iterrows():
    #If geocoding is exact, we'll search by coordinate
    if row['GeoMatchLevel'] in ('ADDR', 'POINT', 'USER'): # original was GeoMatchLevelCode
        requestURL = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={0},{1}&radius=1000&rankyby=distance&key={2}'.format(row['Latitude'],row['Longitude'], apiKey)
        pointSearch = 1
    #Otherwise, we'll search by location name and address
    else:
        fullAddress=str(row['LocationName']).replace(' ', '%20')+','+str(row['Street']).replace(' ', '%20')+',%20'+str(row['City']).replace(' ', '%20')+',%20'+row['Area']+',%20'+str(row['PostalCode'])+row['Country']
        #print(fullAddress)
        fullAddress = str(fullAddress)
        requestURL = 'https://maps.googleapis.com/maps/api/place/textsearch/json?query={0}&radius=1000&key={1}'.format(fullAddress, apiKey)
        pointSearch=0
    #Submit request
    response = requests.get(requestURL)
    
    #Parse if the response is okay
    if response.ok:
        responsePy = json.loads(response.text)
        resultDict = {'G_Name':[], 'G_Vicinity':[], 'G_Latitude':[], 'G_Longitude':[], 'G_Types':[], 'G_PlaceID':[]}
        for result in responsePy['results']:
            resultDict['G_Latitude'].append(result['geometry']['location']['lat'])
            resultDict['G_Longitude'].append(result['geometry']['location']['lng'])
            resultDict['G_Name'].append(result['name'])
            resultDict['G_PlaceID'].append(result['place_id'])
            resultDict['G_Types'].append(concatTypes(result['types']))
            if pointSearch == 1:
                if 'vicinity' not in result:
                    print('Error: No value for vicinity in results')
                    resultDict['G_Vicinity'].append(None)
                else:
                    resultDict['G_Vicinity'].append(result['vicinity'])
            else:
                resultDict['G_Vicinity'].append(result['formatted_address'])
        #Save the results
        currentResultDf=pd.DataFrame.from_dict(resultDict)
        currentResultDf['LocationID'] = row['LocationID'] # original is LocationSID
        masterResults = masterResults.append(currentResultDf, ignore_index = True)
    else:
        print('Bad response: '+requestURL)
        print(response.status_code)
        print(response.reason)
# Out:
# Error: No value for vicinity in results
# Error: No value for vicinity in results
# Error: No value for vicinity in results
# Error: No value for vicinity in results
# Error: No value for vicinity in results
# Error: No value for vicinity in results
# Error: No value for vicinity in results
# Error: No value for vicinity in results
# Error: No value for vicinity in results
# Error: No value for vicinity in results

# %%
locations.merge(masterResults, on='LocationID')
# Out:
#          Type                     ContractID  \
# 0      Target      CBS Corporation 2018-4399
# 1      Target      CBS Corporation 2018-4399
# 2      Target      CBS Corporation 2018-4399
# 3      Target      CBS Corporation 2018-4399
# 4      Target      CBS Corporation 2018-4399
# ...       ...                            ...
# 17214  Target  Florida Municipal Insura-4467
# 17215  Target  Florida Municipal Insura-4467
# 17216  Target  Florida Municipal Insura-4467
# 17217  Target  Florida Municipal Insura-4467
# 17218  Target  Florida Municipal Insura-4467
#
#                                   LocationID         LocationName  \
# 0          CBS Corporation 2018-4399-1697081      CBS TV Stations
# 1          CBS Corporation 2018-4399-1697081      CBS TV Stations
# 2          CBS Corporation 2018-4399-1697081      CBS TV Stations
# 3          CBS Corporation 2018-4399-1697081      CBS TV Stations
# 4          CBS Corporation 2018-4399-1697081      CBS TV Stations
# ...                                      ...                  ...
# 17214  Florida Municipal Insura-4467-1968023  City of Fort Pierce
# 17215  Florida Municipal Insura-4467-1968023  City of Fort Pierce
# 17216  Florida Municipal Insura-4467-1968023  City of Fort Pierce
# 17217  Florida Municipal Insura-4467-1968023  City of Fort Pierce
# 17218  Florida Municipal Insura-4467-1968023  City of Fort Pierce
#
#       InceptionDate ExpirationDate                Street         City Area  \
# 0        2018-08-01     2019-08-01  8900 NW 18TH TERRACE        MIAMI   FL
# 1        2018-08-01     2019-08-01  8900 NW 18TH TERRACE        MIAMI   FL
# 2        2018-08-01     2019-08-01  8900 NW 18TH TERRACE        MIAMI   FL
# 3        2018-08-01     2019-08-01  8900 NW 18TH TERRACE        MIAMI   FL
# 4        2018-08-01     2019-08-01  8900 NW 18TH TERRACE        MIAMI   FL
# ...             ...            ...                   ...          ...  ...
# 17214    2019-04-01     2020-04-01        100 NORTH US 1  FORT PIERCE   FL
# 17215    2019-04-01     2020-04-01        100 NORTH US 1  FORT PIERCE   FL
# 17216    2019-04-01     2020-04-01        100 NORTH US 1  FORT PIERCE   FL
# 17217    2019-04-01     2020-04-01        100 NORTH US 1  FORT PIERCE   FL
# 17218    2019-04-01     2020-04-01        100 NORTH US 1  FORT PIERCE   FL
#
#           SubArea  ... BuildingHeight  BuildingHeightUnitCode FloorArea  \
# 0      MIAMI-DADE  ...              0                       M         0
# 1      MIAMI-DADE  ...              0                       M         0
# 2      MIAMI-DADE  ...              0                       M         0
# 3      MIAMI-DADE  ...              0                       M         0
# 4      MIAMI-DADE  ...              0                       M         0
# ...           ...  ...            ...                     ...       ...
# 17214   ST. LUCIE  ...              0                       M     54270
# 17215   ST. LUCIE  ...              0                       M     54270
# 17216   ST. LUCIE  ...              0                       M     54270
# 17217   ST. LUCIE  ...              0                       M     54270
# 17218   ST. LUCIE  ...              0                       M     54270
#
#        FloorAreaUnitCode                                             G_Name  \
# 0                   SQFT                                      Fontainebleau
# 1                   SQFT  Extended Stay America - Miami - Airport - Dora...
# 2                   SQFT                    InterContinental at Doral Miami
# 3                   SQFT                           Walmart Vision & Glasses
# 4                   SQFT                                Walmart Supercenter
# ...                  ...                                                ...
# 17214               SQFT                         US Agricultural Department
# 17215               SQFT                                  Housing Authority
# 17216               SQFT                               US Marshals Services
# 17217               SQFT                                                KFC
# 17218               SQFT                    First International Title, Inc.
#
#                                       G_Vicinity  G_Latitude  G_Longitude  \
# 0                                  Fontainebleau   25.772877   -80.347830
# 1             8655 Northwest 21st Terrace, Miami   25.794389   -80.336302
# 2              2505 Northwest 87th Avenue, Doral   25.797556   -80.335944
# 3             8651 Northwest 13th Terrace, Doral   25.786939   -80.335410
# 4             8651 Northwest 13th Terrace, Doral   25.786939   -80.335410
# ...                                          ...         ...          ...
# 17214  200 South Indian River Drive, Fort Pierce   27.447169   -80.322441
# 17215                  601 Avenue B, Fort Pierce   27.446862   -80.327783
# 17216          300 South 6th Street, Fort Pierce   27.444648   -80.327876
# 17217    405 South North 4th Street, Fort Pierce   27.443578   -80.326263
# 17218          107 North 2nd Street, Fort Pierce   27.447818   -80.324065
#
#                                                  G_Types  \
# 0                                     locality,political
# 1                lodging,point_of_interest,establishment
# 2                lodging,point_of_interest,establishment
# 3           health,point_of_interest,store,establishment
# 4      department_store,supermarket,grocery_or_superm...
# ...                                                  ...
# 17214                    point_of_interest,establishment
# 17215  local_government_office,point_of_interest,esta...
# 17216                    point_of_interest,establishment
# 17217    restaurant,food,point_of_interest,establishment
# 17218   insurance_agency,point_of_interest,establishment
#
#                          G_PlaceID
# 0      ChIJf3xCQyG52YgRfjnC-jmC70M
# 1      ChIJsckpR2y52YgRqt9C-FTsF3Q
# 2      ChIJuzAKwG652YgRMBa6hse5_AA
# 3      ChIJ7-zIrhO52YgRNQ1iWYWUgRw
# 4      ChIJ7-zIrhO52YgRlgVriA-g83g
# ...                            ...
# 17214  ChIJTS5SSQDx3ogRB1Qw5u1r_YA
# 17215  ChIJ36x1cgfx3ogRPU8AJjQQU50
# 17216  ChIJ912bmanx3ogRP53nf5tM3VU
# 17217  ChIJV4cYzKvx3ogRENKhptHgZag
# 17218  ChIJnbrwbADx3ogR2PtFF_jrpYE
#
# [17219 rows x 151 columns]

# %%
masterResults
# Out:
#                                                   G_Name  \
# 0                                          Fontainebleau
# 1      Extended Stay America - Miami - Airport - Dora...
# 2                        InterContinental at Doral Miami
# 3                               Walmart Vision & Glasses
# 4                                    Walmart Supercenter
# ...                                                  ...
# 17214                         US Agricultural Department
# 17215                                  Housing Authority
# 17216                               US Marshals Services
# 17217                                                KFC
# 17218                    First International Title, Inc.
#
#                                       G_Vicinity  G_Latitude  G_Longitude  \
# 0                                  Fontainebleau   25.772877   -80.347830
# 1             8655 Northwest 21st Terrace, Miami   25.794389   -80.336302
# 2              2505 Northwest 87th Avenue, Doral   25.797556   -80.335944
# 3             8651 Northwest 13th Terrace, Doral   25.786939   -80.335410
# 4             8651 Northwest 13th Terrace, Doral   25.786939   -80.335410
# ...                                          ...         ...          ...
# 17214  200 South Indian River Drive, Fort Pierce   27.447169   -80.322441
# 17215                  601 Avenue B, Fort Pierce   27.446862   -80.327783
# 17216          300 South 6th Street, Fort Pierce   27.444648   -80.327876
# 17217    405 South North 4th Street, Fort Pierce   27.443578   -80.326263
# 17218          107 North 2nd Street, Fort Pierce   27.447818   -80.324065
#
#                                                  G_Types  \
# 0                                     locality,political
# 1                lodging,point_of_interest,establishment
# 2                lodging,point_of_interest,establishment
# 3           health,point_of_interest,store,establishment
# 4      department_store,supermarket,grocery_or_superm...
# ...                                                  ...
# 17214                    point_of_interest,establishment
# 17215  local_government_office,point_of_interest,esta...
# 17216                    point_of_interest,establishment
# 17217    restaurant,food,point_of_interest,establishment
# 17218   insurance_agency,point_of_interest,establishment
#
#                          G_PlaceID                             LocationID
# 0      ChIJf3xCQyG52YgRfjnC-jmC70M      CBS Corporation 2018-4399-1697081
# 1      ChIJsckpR2y52YgRqt9C-FTsF3Q      CBS Corporation 2018-4399-1697081
# 2      ChIJuzAKwG652YgRMBa6hse5_AA      CBS Corporation 2018-4399-1697081
# 3      ChIJ7-zIrhO52YgRNQ1iWYWUgRw      CBS Corporation 2018-4399-1697081
# 4      ChIJ7-zIrhO52YgRlgVriA-g83g      CBS Corporation 2018-4399-1697081
# ...                            ...                                    ...
# 17214  ChIJTS5SSQDx3ogRB1Qw5u1r_YA  Florida Municipal Insura-4467-1968023
# 17215  ChIJ36x1cgfx3ogRPU8AJjQQU50  Florida Municipal Insura-4467-1968023
# 17216  ChIJ912bmanx3ogRP53nf5tM3VU  Florida Municipal Insura-4467-1968023
# 17217  ChIJV4cYzKvx3ogRENKhptHgZag  Florida Municipal Insura-4467-1968023
# 17218  ChIJnbrwbADx3ogR2PtFF_jrpYE  Florida Municipal Insura-4467-1968023
#
# [17219 rows x 7 columns]

# %%
masterResults['G_Vicinity']
# Out:
# 0                                    Fontainebleau
# 1               8655 Northwest 21st Terrace, Miami
# 2                2505 Northwest 87th Avenue, Doral
# 3               8651 Northwest 13th Terrace, Doral
# 4               8651 Northwest 13th Terrace, Doral
#                            ...
# 17214    200 South Indian River Drive, Fort Pierce
# 17215                    601 Avenue B, Fort Pierce
# 17216            300 South 6th Street, Fort Pierce
# 17217      405 South North 4th Street, Fort Pierce
# 17218            107 North 2nd Street, Fort Pierce
# Name: G_Vicinity, Length: 17219, dtype: object
